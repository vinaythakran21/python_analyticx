# %% [markdown]
# # Pandas Exercise: Time Series (Getting Financial Data - Google Finance)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime
import quandl

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
start=datetime.datetime(2015,1,1)
end=datetime.datetime.today()

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stocks = ['EOD/AAPL', 'SSE/TL0', 'EOD/IBM']

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
quandl.ApiConfig.api_key='KVQTC24xS5Q72ofZH9gZ'

# %%
df=quandl.get(stocks,start_date=start,end_date=end)
df.head()
# Out:
#             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2015-01-02           111.39           111.44         107.350
# 2015-01-05           108.29           108.65         105.410
# 2015-01-06           106.54           107.43         104.630
# 2015-01-07           107.20           108.20         106.695
# 2015-01-08           109.23           112.15         108.700
#
#             EOD/AAPL - Close  EOD/AAPL - Volume  EOD/AAPL - Dividend  \
# Date
# 2015-01-02            109.33         53204626.0                  0.0
# 2015-01-05            106.25         64285491.0                  0.0
# 2015-01-06            106.26         65797116.0                  0.0
# 2015-01-07            107.75         40105934.0                  0.0
# 2015-01-08            111.89         59364547.0                  0.0
#
#             EOD/AAPL - Split  EOD/AAPL - Adj_Open  EOD/AAPL - Adj_High  \
# Date
# 2015-01-02               1.0           104.246170           104.292963
# ...

# %%
df.tail()
# Out:
#             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2018-08-20           218.10           219.18         215.110
# 2018-08-21           216.80           217.19         214.025
# 2018-08-22           214.10           216.36         213.840
# 2018-08-23           214.65           217.05         214.600
# 2018-08-24           216.60           216.90         215.110
#
#             EOD/AAPL - Close  EOD/AAPL - Volume  EOD/AAPL - Dividend  \
# Date
# 2018-08-20            215.46         30287695.0                  0.0
# 2018-08-21            215.04         26159755.0                  0.0
# 2018-08-22            215.05         19018131.0                  0.0
# 2018-08-23            215.49         18883224.0                  0.0
# 2018-08-24            216.16         18476356.0                  0.0
#
#             EOD/AAPL - Split  EOD/AAPL - Adj_Open  EOD/AAPL - Adj_High  \
# Date
# 2018-08-20               1.0               218.10               219.18
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
df.items
# Out:
# <bound method DataFrame.iteritems of             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2015-01-02         111.3900         111.4400        107.3500
# 2015-01-05         108.2900         108.6500        105.4100
# 2015-01-06         106.5400         107.4300        104.6300
# 2015-01-07         107.2000         108.2000        106.6950
# 2015-01-08         109.2300         112.1500        108.7000
# 2015-01-09         112.6700         113.2500        110.2100
# 2015-01-12         112.6000         112.6300        108.8000
# 2015-01-13         111.4300         112.8000        108.9100
# 2015-01-14         109.0400         110.4900        108.5000
# 2015-01-15         110.0000         110.0600        106.6600
# 2015-01-16         107.0300         107.5800        105.2000
# 2015-01-19              NaN              NaN             NaN
# 2015-01-20         107.8400         108.9667        106.5000
# 2015-01-21         108.9500         111.0600        108.2700
# ...

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 941 entries, 2015-01-02 to 2018-08-24
# Data columns (total 29 columns):
# EOD/AAPL - Open                 919 non-null float64
# EOD/AAPL - High                 919 non-null float64
# EOD/AAPL - Low                  919 non-null float64
# EOD/AAPL - Close                919 non-null float64
# EOD/AAPL - Volume               919 non-null float64
# EOD/AAPL - Dividend             919 non-null float64
# EOD/AAPL - Split                919 non-null float64
# EOD/AAPL - Adj_Open             919 non-null float64
# EOD/AAPL - Adj_High             919 non-null float64
# EOD/AAPL - Adj_Low              919 non-null float64
# EOD/AAPL - Adj_Close            919 non-null float64
# EOD/AAPL - Adj_Volume           919 non-null float64
# SSE/TL0 - High                  875 non-null float64
# SSE/TL0 - Low                   875 non-null float64
# SSE/TL0 - Last                  875 non-null float64
# ...

# %%
vol=pd.DataFrame()
vol['EOD/AAPL - Volume']=df['EOD/AAPL - Volume']
vol['SSE/TL0 - Volume']=df['SSE/TL0 - Volume']
vol['EOD/IBM - Volume']=df['EOD/IBM - Volume']

# %%
vol.head()
# Out:
#             EOD/AAPL - Volume  SSE/TL0 - Volume  EOD/IBM - Volume
# Date
# 2015-01-02         53204626.0               NaN         5525341.0
# 2015-01-05         64285491.0               NaN         4880389.0
# 2015-01-06         65797116.0               NaN         6145670.0
# 2015-01-07         40105934.0               NaN         4701015.0
# 2015-01-08         59364547.0               NaN         4240585.0

# %%
vol.tail()
# Out:
#             EOD/AAPL - Volume  SSE/TL0 - Volume  EOD/IBM - Volume
# Date
# 2018-08-20         30287695.0             432.0         2499654.0
# 2018-08-21         26159755.0             300.0         3105655.0
# 2018-08-22         19018131.0             361.0         2388955.0
# 2018-08-23         18883224.0              77.0         2220603.0
# 2018-08-24         18476356.0             194.0         2776615.0

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol.resample('W').mean().interpolate()
# Out:
#             EOD/AAPL - Volume  SSE/TL0 - Volume  EOD/IBM - Volume
# Date
# 2015-01-04        53204626.00               NaN        5525341.00
# 2015-01-11        56573637.40               NaN        4888072.00
# 2015-01-18        60845329.40               NaN        4654411.20
# 2015-01-25        49684260.25               NaN        7807699.25
# 2015-02-01        93168536.80               NaN        6585461.40
# 2015-02-08        54151480.80               NaN        4487966.00
# 2015-02-15        60641357.00               NaN        3632951.20
# 2015-02-22        48588735.50               NaN        3527223.00
# 2015-03-01        73643272.40               NaN        4588245.40
# 2015-03-08        49387698.40               NaN        4223409.80
# 2015-03-15        65302809.00               NaN        5227089.60
# 2015-03-22        53334595.00               NaN        5136974.40
# 2015-03-29        41865235.00               NaN        4713842.60
# ...

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
vol[vol.index.year==2015].sum()
# Out:
# EOD/AAPL - Volume    1.306432e+10
# SSE/TL0 - Volume     0.000000e+00
# EOD/IBM - Volume     1.105546e+09
# dtype: float64

# %% [markdown]
# ### BONUS: Create your own question and answer it.
