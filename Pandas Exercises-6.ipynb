# %% [markdown]
# # Pandas Exercise: Merging (MPG Cars)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1=pd.read_csv("C:\\Users\Sumeet Chaudhary\Desktop\ALABS\Pandas Case Study\\0. Data\cars1.csv")
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
cars2=pd.read_csv('C:\\Users\Sumeet Chaudhary\Desktop\ALABS\Pandas Case Study\\0. Data\cars2.csv')
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 14 columns):
# mpg             198 non-null float64
# cylinders       198 non-null int64
# displacement    198 non-null int64
# horsepower      198 non-null object
# weight          198 non-null int64
# acceleration    198 non-null float64
# model           198 non-null int64
# origin          198 non-null int64
# car             198 non-null object
# Unnamed: 9      0 non-null float64
# Unnamed: 10     0 non-null float64
# Unnamed: 11     0 non-null float64
# Unnamed: 12     0 non-null float64
# Unnamed: 13     0 non-null float64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 20.1+ KB

# %%
cars2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
# mpg             200 non-null float64
# cylinders       200 non-null int64
# displacement    200 non-null int64
# horsepower      200 non-null object
# weight          200 non-null int64
# acceleration    200 non-null float64
# model           200 non-null int64
# origin          200 non-null int64
# car             200 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 12.5+ KB

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.drop(['Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'],axis=1,inplace=True)
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
# mpg             198 non-null float64
# cylinders       198 non-null int64
# displacement    198 non-null int64
# horsepower      198 non-null object
# weight          198 non-null int64
# acceleration    198 non-null float64
# model           198 non-null int64
# origin          198 non-null int64
# car             198 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 12.4+ KB

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars1=pd.merge(cars1,cars2,how='outer')
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import random
r1=random.sample(range(15000,73000),398)
r1
# Out:
# [39254,
#  45709,
#  48814,
#  56040,
#  61205,
#  70364,
#  54784,
#  55142,
#  24914,
#  47750,
#  41906,
#  34205,
#  54589,
#  72390,
#  40103,
#  46684,
#  54044,
#  53831,
#  33950,
#  24958,
#  59397,
#  70115,
#  41336,
#  50136,
#  72042,
#  68111,
#  24969,
#  20461,
#  67599,
#  45897,
#  48656,
#  22733,
#  39619,
#  16250,
#  34910,
#  48067,
#  28397,
#  55940,
#  40630,
#  30896,
#  59102,
#  54545,
#  16680,
#  31101,
#  58478,
#  47462,
#  49355,
#  47429,
#  52747,
#  68474,
#  70861,
#  35132,
#  61134,
#  68858,
#  29681,
#  35949,
#  48062,
#  34859,
#  35656,
#  28456,
#  28779,
#  64312,
#  57581,
#  26164,
#  69138,
#  29219,
#  45704,
#  49651,
#  33778,
#  68874,
#  55969,
#  48736,
#  62286,
#  38728,
#  40301,
#  39300,
#  29137,
#  52500,
#  65530,
#  19088,
#  24258,
#  15920,
#  45236,
#  34121,
#  48950,
#  58557,
#  64935,
#  22036,
#  15806,
#  32266,
#  67088,
#  56146,
#  72249,
#  55469,
#  69098,
#  64069,
#  32205,
#  57049,
#  40892,
#  20763,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars1['owners']=pd.DataFrame(r1)
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owners
# 0       1  chevrolet chevelle malibu   39254
# 1       1          buick skylark 320   45709
# 2       1         plymouth satellite   48814
# 3       1              amc rebel sst   56040
# 4       1                ford torino   61205
