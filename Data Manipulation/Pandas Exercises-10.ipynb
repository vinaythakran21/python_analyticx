# %% [markdown]
# # Pandas Exercise: Time Series (Apple Stock)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Time_Series/Apple_Stock/appl_1980_2014.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple=pd.read_csv("C:\\Users\Sumeet Chaudhary\Desktop\ALABS\Pandas Case Study\\0. Data\\appl_1980_2014.csv")
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
# Date         8465 non-null object
# Open         8465 non-null float64
# High         8465 non-null float64
# Low          8465 non-null float64
# Close        8465 non-null float64
# Volume       8465 non-null int64
# Adj Close    8465 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 429.9+ KB

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date']=pd.to_datetime(apple.Date)
apple.head()
# Out:
#         Date   Open   High    Low  Close    Volume  Adj Close
# 0 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.set_index('Date',inplace=True,verify_integrity=True)
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple.sort_index().head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple.resample('M').interpolate()
# Out:
#                   Open        High      Low    Close       Volume  Adj Close
# Date
# 1980-12-31   34.250000   34.250000   34.130   34.130    8937600.0   0.530000
# 1981-01-31   31.083333   31.083333   30.920   30.920    7291200.0   0.480000
# 1981-02-28   27.916667   27.916667   27.710   27.710    5644800.0   0.430000
# 1981-03-31   24.750000   24.750000   24.500   24.500    3998400.0   0.380000
# 1981-04-30   28.380000   28.620000   28.380   28.380    3152800.0   0.440000
# 1981-05-31   27.255000   27.375000   27.190   27.190    6064800.0   0.425000
# 1981-06-30   26.130000   26.130000   26.000   26.000    8976800.0   0.410000
# 1981-07-31   25.000000   25.120000   25.000   25.000    2738400.0   0.390000
# 1981-08-31   20.130000   20.250000   20.130   20.130   10236800.0   0.310000
# 1981-09-30   15.250000   15.370000   15.250   15.250   12499200.0   0.240000
# 1981-10-31   17.000000   17.060000   16.940   16.940    9245600.0   0.265000
# ...

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
delta = apple.index.max() - apple.index.min()
delta.days
# Out:
# 12261

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
apple.resample('M').interpolate().Open.count()
# Out:
# 404

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import matplotlib as plt
# %matplotlib inline
apple['Adj Close'].plot(kind='line',figsize=(13.5,9))

# %% [markdown]
# ### BONUS: Create your own question and answer it.
